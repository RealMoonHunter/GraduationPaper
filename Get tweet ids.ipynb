# %% [markdown]
# ### Extract Tweet ids from Tweet urls in Synthesio dataset
# #### 04/03 2022

# %%
import pandas as pd
import numpy as np
import time
import os

# %%
def count(str): 
    n = str.count('/') #check string structure
    return n

# %%
def cuttweetid(str):
    ID = str.split("#")[0].split("/")[5] #These url strings share similar feactures: has one #, and five /
    return ID

# %%
def getid(dataframe):
    IDs = []
    for i in dataframe["Mention URL"]:
        try:
            if i != 'Deleted or protected mention':
                IDs.append(cuttweetid(i))
            else:
                IDs.append('Deleted or protected mention')
        except Exception as e:
            IDs.append('Error')
            print(e)
    
    return IDs

# %%
#'Error' in IDs

# %%
newfilename_list = []
path = '.././covid datasets/Synthesio_covid_English_National/archive/data_checked/March/' #March, April, May
id_path = '.././covid datasets/Synthesio_covid_English_National/archive/data_checked/Tweet IDs/'
for root, dirs, files in os.walk(path):
    for filename in files:
        
        if "export" in filename and "._" not in filename:
            tic = time.time()
            data = pd.read_csv(path + filename, encoding ='latin-1')
            results = getid(data)
         
            newfilename = filename.replace('export_mentions','tweetids')[:-4]
            print(newfilename)
            newfilename_list.append(newfilename)
            
            
            with open(id_path + newfilename + ".txt", "w") as output:
                output.write(str(results) + '\n')
            
            print("Length is consitent: ", len(results) == len(data))
            print("No Error occurs: ", 'Error' not in results) #check if there is an error
            toc = time.time()
            print("Now is ", time.ctime(toc), ", we spent ", round(toc - tic, 2),  " s for the last processing task.")
# Out:
# tweetids_219404_359708_2020-09-26T18 18 16
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:51 2022 , we spent  0.23  s for the last processing task.
# tweetids_219404_359708_2020-09-26T18 23 21
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:52 2022 , we spent  0.16  s for the last processing task.
# tweetids_219404_359708_2020-09-26T18 26 56
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:52 2022 , we spent  0.36  s for the last processing task.
# tweetids_219404_359708_2020-09-26T18 34 01
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:53 2022 , we spent  0.59  s for the last processing task.
# tweetids_219404_359708_2020-09-26T18 45 07
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:53 2022 , we spent  0.57  s for the last processing task.
# tweetids_219404_359708_2020-09-26T18 56 42
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:54 2022 , we spent  0.48  s for the last processing task.
# tweetids_219404_359708_2020-09-26T19 06 18
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:54 2022 , we spent  0.52  s for the last processing task.
# tweetids_219404_359708_2020-09-26T19 16 23
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:55 2022 , we spent  0.43  s for the last processing task.
# tweetids_219404_359708_2020-09-26T19 24 59
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:55 2022 , we spent  0.24  s for the last processing task.
# tweetids_219404_359708_2020-09-26T19 30 04
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:55 2022 , we spent  0.15  s for the last processing task.
# tweetids_219404_359708_2020-09-26T19 33 39
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:55 2022 , we spent  0.34  s for the last processing task.
# tweetids_219404_359708_2020-09-26T19 40 44
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:56 2022 , we spent  0.47  s for the last processing task.
# tweetids_219404_359708_2020-09-26T19 50 19
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:56 2022 , we spent  0.48  s for the last processing task.
# tweetids_219404_359708_2020-09-26T20 00 25
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:57 2022 , we spent  0.42  s for the last processing task.
# tweetids_219404_359708_2020-09-26T20 09 00
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:57 2022 , we spent  0.4  s for the last processing task.
# tweetids_219404_359708_2020-09-26T20 17 06
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:57 2022 , we spent  0.33  s for the last processing task.
# tweetids_219404_359708_2020-09-26T20 23 41
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:58 2022 , we spent  0.17  s for the last processing task.
# tweetids_219404_359708_2020-09-26T20 27 46
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:58 2022 , we spent  0.13  s for the last processing task.
# tweetids_219404_359708_2020-09-26T20 30 52
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:58 2022 , we spent  0.36  s for the last processing task.
# tweetids_219404_359708_2020-09-26T20 37 25
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:59 2022 , we spent  0.54  s for the last processing task.
# tweetids_219404_359708_2020-09-26T20 47 31
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:48:59 2022 , we spent  0.52  s for the last processing task.
# tweetids_219404_359708_2020-09-26T20 57 36
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:00 2022 , we spent  0.46  s for the last processing task.
# tweetids_219404_359708_2020-09-26T21 06 11
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:00 2022 , we spent  0.41  s for the last processing task.
# tweetids_219404_359708_2020-09-26T22 11 57
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:00 2022 , we spent  0.4  s for the last processing task.
# tweetids_219404_359708_2020-09-26T22 19 33
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:01 2022 , we spent  0.2  s for the last processing task.
# tweetids_219404_359708_2020-09-26T22 23 38
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:01 2022 , we spent  0.14  s for the last processing task.
# tweetids_219404_359708_2020-09-26T22 27 13
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:01 2022 , we spent  0.36  s for the last processing task.
# tweetids_219404_359708_2020-09-26T22 34 18
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:02 2022 , we spent  0.53  s for the last processing task.
# tweetids_219404_359708_2020-09-26T22 45 12
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:02 2022 , we spent  0.57  s for the last processing task.
# tweetids_219404_359708_2020-09-26T22 55 47
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:03 2022 , we spent  0.52  s for the last processing task.
# tweetids_219404_359708_2020-09-26T23 05 23
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:03 2022 , we spent  0.46  s for the last processing task.
# tweetids_219404_359708_2020-09-26T23 15 12
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:04 2022 , we spent  0.43  s for the last processing task.
# tweetids_219404_359708_2020-09-26T23 24 08
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:04 2022 , we spent  0.26  s for the last processing task.
# tweetids_219404_359708_2020-09-26T23 29 15
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:04 2022 , we spent  0.16  s for the last processing task.
# tweetids_219404_359708_2020-09-26T23 32 49
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:04 2022 , we spent  0.44  s for the last processing task.
# tweetids_219404_359708_2020-09-26T23 41 24
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:05 2022 , we spent  0.61  s for the last processing task.
# tweetids_219404_359708_2020-09-26T23 53 55
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:06 2022 , we spent  0.56  s for the last processing task.
# tweetids_219404_359708_2020-09-27T00 10 27
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:06 2022 , we spent  0.48  s for the last processing task.
# tweetids_219404_359708_2020-09-27T00 31 14
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:06 2022 , we spent  0.39  s for the last processing task.
# tweetids_219404_359708_2020-09-27T00 38 23
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:07 2022 , we spent  0.28  s for the last processing task.
# tweetids_219404_359708_2020-09-27T00 42 17
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:07 2022 , we spent  0.18  s for the last processing task.
# tweetids_219404_359708_2020-09-27T00 46 23
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:07 2022 , we spent  0.11  s for the last processing task.
# tweetids_219404_359708_2020-09-27T00 49 29
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:07 2022 , we spent  0.27  s for the last processing task.
# tweetids_219404_359708_2020-09-27T00 55 04
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:08 2022 , we spent  0.41  s for the last processing task.
# tweetids_219404_359708_2020-09-27T01 03 10
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:08 2022 , we spent  0.44  s for the last processing task.
# tweetids_219404_359708_2020-09-27T01 11 46
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:09 2022 , we spent  0.39  s for the last processing task.
# tweetids_219404_359708_2020-09-27T01 19 52
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:09 2022 , we spent  0.36  s for the last processing task.
# tweetids_219404_359708_2020-09-27T01 26 58
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:09 2022 , we spent  0.28  s for the last processing task.
# tweetids_219404_359708_2020-09-27T01 33 04
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:09 2022 , we spent  0.16  s for the last processing task.
# tweetids_219404_359708_2020-09-27T01 36 41
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:09 2022 , we spent  0.11  s for the last processing task.
# tweetids_219404_359708_2020-09-27T01 39 47
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:10 2022 , we spent  0.24  s for the last processing task.
# tweetids_219404_359708_2020-09-27T01 44 52
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:10 2022 , we spent  0.36  s for the last processing task.
# tweetids_219404_359708_2020-09-27T01 51 59
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:10 2022 , we spent  0.35  s for the last processing task.
# tweetids_219404_359708_2020-09-27T01 59 35
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:11 2022 , we spent  0.31  s for the last processing task.
# tweetids_219404_359708_2020-09-27T02 05 41
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:11 2022 , we spent  0.28  s for the last processing task.
# tweetids_219404_359708_2020-09-27T02 11 17
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:11 2022 , we spent  0.27  s for the last processing task.
# tweetids_219404_359708_2020-09-27T02 16 53
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:11 2022 , we spent  0.14  s for the last processing task.
# tweetids_219404_359708_2020-09-27T02 20 29
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:12 2022 , we spent  0.12  s for the last processing task.
# tweetids_219404_359708_2020-09-27T02 23 35
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:12 2022 , we spent  0.31  s for the last processing task.
# tweetids_219404_359708_2020-09-27T02 29 41
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:12 2022 , we spent  0.45  s for the last processing task.
# tweetids_219404_359708_2020-09-27T02 38 17
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:13 2022 , we spent  0.53  s for the last processing task.
# tweetids_219404_359708_2020-09-27T02 50 31
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:13 2022 , we spent  0.48  s for the last processing task.
# tweetids_219404_359708_2020-09-27T03 00 07
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:14 2022 , we spent  0.43  s for the last processing task.
# tweetids_219404_359708_2020-09-27T03 08 43
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:14 2022 , we spent  0.36  s for the last processing task.
# tweetids_219404_359708_2020-09-27T03 15 49
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:14 2022 , we spent  0.18  s for the last processing task.
# tweetids_219404_359708_2020-09-27T03 19 54
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:14 2022 , we spent  0.14  s for the last processing task.
# tweetids_219404_359708_2020-09-27T03 23 00
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:15 2022 , we spent  0.35  s for the last processing task.
# tweetids_219404_359708_2020-09-27T03 32 10
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:15 2022 , we spent  0.48  s for the last processing task.
# tweetids_219404_359708_2020-09-27T04 38 28
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:16 2022 , we spent  0.49  s for the last processing task.
# tweetids_219404_359708_2020-09-27T04 48 04
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:16 2022 , we spent  0.42  s for the last processing task.
# tweetids_219404_359708_2020-09-27T04 57 28
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:17 2022 , we spent  0.38  s for the last processing task.
# tweetids_219404_359708_2020-09-27T05 05 53
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:17 2022 , we spent  0.32  s for the last processing task.
# tweetids_219404_359708_2020-09-27T05 12 46
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:17 2022 , we spent  0.15  s for the last processing task.
# tweetids_219404_359708_2020-09-27T05 16 22
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:17 2022 , we spent  0.13  s for the last processing task.
# tweetids_219404_359708_2020-09-27T05 19 27
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:17 2022 , we spent  0.36  s for the last processing task.
# tweetids_219404_359708_2020-09-27T05 27 16
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:18 2022 , we spent  0.54  s for the last processing task.
# tweetids_219404_359708_2020-09-27T05 37 38
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:19 2022 , we spent  0.54  s for the last processing task.
# tweetids_219404_359708_2020-09-27T06 15 16
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:19 2022 , we spent  0.45  s for the last processing task.
# tweetids_219404_359708_2020-09-27T06 26 22
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:19 2022 , we spent  0.42  s for the last processing task.
# tweetids_219404_359708_2020-09-27T06 37 12
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:20 2022 , we spent  0.33  s for the last processing task.
# tweetids_219404_359708_2020-09-27T06 47 11
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:20 2022 , we spent  0.16  s for the last processing task.
# tweetids_219404_359708_2020-09-27T06 51 16
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:20 2022 , we spent  0.13  s for the last processing task.
# tweetids_219404_359708_2020-09-27T06 55 41
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:20 2022 , we spent  0.38  s for the last processing task.
# tweetids_219404_359708_2020-09-27T07 03 17
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:21 2022 , we spent  0.57  s for the last processing task.
# tweetids_219404_359708_2020-09-27T07 13 53
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:22 2022 , we spent  0.57  s for the last processing task.
# tweetids_219404_359708_2020-09-27T07 23 29
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:22 2022 , we spent  0.57  s for the last processing task.
# tweetids_219404_359708_2020-09-27T07 33 35
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:23 2022 , we spent  0.55  s for the last processing task.
# tweetids_219404_359708_2020-09-27T07 43 41
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:23 2022 , we spent  0.4  s for the last processing task.
# tweetids_219404_359708_2020-09-27T07 51 47
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:23 2022 , we spent  0.2  s for the last processing task.
# tweetids_219404_359708_2020-09-27T07 56 23
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:23 2022 , we spent  0.15  s for the last processing task.
# tweetids_219404_359708_2020-09-27T07 59 58
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:24 2022 , we spent  0.38  s for the last processing task.
# tweetids_219404_359708_2020-09-27T08 07 34
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:24 2022 , we spent  0.58  s for the last processing task.
# tweetids_219404_359708_2020-09-27T08 18 10
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:25 2022 , we spent  0.58  s for the last processing task.
# tweetids_219404_359708_2020-09-27T08 28 46
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:26 2022 , we spent  0.55  s for the last processing task.
# tweetids_219404_359708_2020-09-27T08 38 52
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:26 2022 , we spent  0.43  s for the last processing task.
# tweetids_219404_359708_2020-09-27T08 49 10
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:26 2022 , we spent  0.37  s for the last processing task.
# tweetids_219404_359708_2020-09-27T08 57 34
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:27 2022 , we spent  0.17  s for the last processing task.
# tweetids_219404_359708_2020-09-27T09 01 39
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:27 2022 , we spent  0.12  s for the last processing task.
# tweetids_219404_359708_2020-09-27T09 04 44
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:27 2022 , we spent  0.29  s for the last processing task.
# tweetids_219404_359708_2020-09-27T09 10 20
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:27 2022 , we spent  0.42  s for the last processing task.
# tweetids_219404_359708_2020-09-27T09 18 26
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:28 2022 , we spent  0.44  s for the last processing task.
# tweetids_219404_359708_2020-09-27T09 26 32
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:28 2022 , we spent  0.4  s for the last processing task.
# tweetids_219404_359708_2020-09-27T09 34 10
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:29 2022 , we spent  0.37  s for the last processing task.
# tweetids_219404_359708_2020-09-27T10 38 29
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:29 2022 , we spent  0.34  s for the last processing task.
# tweetids_219404_359708_2020-09-27T10 46 23
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:29 2022 , we spent  0.19  s for the last processing task.
# tweetids_219404_359708_2020-09-27T10 50 29
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:29 2022 , we spent  0.12  s for the last processing task.
# tweetids_219404_359708_2020-09-27T10 53 35
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:29 2022 , we spent  0.25  s for the last processing task.
# tweetids_219404_359708_2020-09-27T10 59 11
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:30 2022 , we spent  0.43  s for the last processing task.
# tweetids_219404_359708_2020-09-27T11 07 47
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:30 2022 , we spent  0.45  s for the last processing task.
# tweetids_219404_359708_2020-09-27T11 16 53
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:31 2022 , we spent  0.51  s for the last processing task.
# tweetids_219404_359708_2020-09-27T11 25 59
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:31 2022 , we spent  0.49  s for the last processing task.
# tweetids_219404_359708_2020-09-27T11 35 06
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:32 2022 , we spent  0.42  s for the last processing task.
# tweetids_219404_359708_2020-09-27T11 43 42
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:32 2022 , we spent  0.23  s for the last processing task.
# tweetids_219404_359708_2020-09-27T11 48 18
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:32 2022 , we spent  0.16  s for the last processing task.
# tweetids_219404_359708_2020-09-27T11 51 53
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:33 2022 , we spent  0.4  s for the last processing task.
# tweetids_219404_359708_2020-09-27T12 00 49
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:33 2022 , we spent  0.67  s for the last processing task.
# tweetids_219404_359708_2020-09-27T12 12 55
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:34 2022 , we spent  0.71  s for the last processing task.
# tweetids_219404_359708_2020-09-27T12 26 32
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:35 2022 , we spent  0.63  s for the last processing task.
# tweetids_219404_359708_2020-09-27T17 39 52
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:35 2022 , we spent  0.53  s for the last processing task.
# tweetids_219404_359708_2020-09-27T17 50 50
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:35 2022 , we spent  0.4  s for the last processing task.
# tweetids_219404_359708_2020-09-27T17 52 33
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:36 2022 , we spent  0.18  s for the last processing task.
# tweetids_219404_359708_2020-09-27T17 57 11
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:36 2022 , we spent  0.15  s for the last processing task.
# tweetids_219404_359708_2020-09-27T18 00 45
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:36 2022 , we spent  0.44  s for the last processing task.
# tweetids_219404_359708_2020-09-27T18 09 51
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:37 2022 , we spent  0.71  s for the last processing task.
# tweetids_219404_359708_2020-09-27T18 22 26
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:38 2022 , we spent  0.75  s for the last processing task.
# tweetids_219404_359708_2020-09-27T18 37 33
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:38 2022 , we spent  0.76  s for the last processing task.
# tweetids_219404_359708_2020-09-27T18 53 27
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:39 2022 , we spent  0.63  s for the last processing task.
# tweetids_219404_359708_2020-09-27T19 06 03
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:40 2022 , we spent  0.49  s for the last processing task.
# tweetids_219404_359708_2020-09-27T19 16 09
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:40 2022 , we spent  0.23  s for the last processing task.
# tweetids_219404_359708_2020-09-27T19 22 03
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:40 2022 , we spent  0.18  s for the last processing task.
# tweetids_219404_359708_2020-09-27T19 27 36
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:41 2022 , we spent  0.49  s for the last processing task.
# tweetids_219404_359708_2020-09-27T19 37 42
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:41 2022 , we spent  0.77  s for the last processing task.
# tweetids_219404_359708_2020-09-27T19 52 17
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:42 2022 , we spent  0.68  s for the last processing task.
# tweetids_219404_359708_2020-09-27T20 04 53
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:43 2022 , we spent  0.55  s for the last processing task.
# tweetids_219404_359708_2020-09-27T20 15 00
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:43 2022 , we spent  0.49  s for the last processing task.
# tweetids_219404_359708_2020-09-27T20 24 06
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:43 2022 , we spent  0.43  s for the last processing task.
# tweetids_219404_359708_2020-09-27T20 32 41
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:44 2022 , we spent  0.2  s for the last processing task.
# tweetids_219404_359708_2020-09-27T20 37 17
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:44 2022 , we spent  0.14  s for the last processing task.
# tweetids_219404_359708_2020-09-27T20 41 36
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:44 2022 , we spent  0.41  s for the last processing task.
# tweetids_219404_359708_2020-09-27T21 48 12
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:45 2022 , we spent  0.59  s for the last processing task.
# tweetids_219404_359708_2020-09-27T22 00 18
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:45 2022 , we spent  0.6  s for the last processing task.
# tweetids_219404_359708_2020-09-27T22 11 53
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:46 2022 , we spent  0.58  s for the last processing task.
# tweetids_219404_359708_2020-09-27T22 23 46
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:46 2022 , we spent  0.5  s for the last processing task.
# tweetids_219404_359708_2020-09-27T22 33 22
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:47 2022 , we spent  0.37  s for the last processing task.
# tweetids_219404_359708_2020-09-27T22 40 57
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:47 2022 , we spent  0.19  s for the last processing task.
# tweetids_219404_359708_2020-09-27T22 45 03
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:47 2022 , we spent  0.14  s for the last processing task.
# tweetids_219404_359708_2020-09-27T22 48 08
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:48 2022 , we spent  0.35  s for the last processing task.
# tweetids_219404_359708_2020-09-27T22 55 13
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:48 2022 , we spent  0.59  s for the last processing task.
# tweetids_219404_359708_2020-09-27T23 06 48
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:49 2022 , we spent  0.62  s for the last processing task.
# tweetids_219404_359708_2020-09-27T23 18 24
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:49 2022 , we spent  0.58  s for the last processing task.
# tweetids_219404_359708_2020-09-27T23 29 00
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:50 2022 , we spent  0.55  s for the last processing task.
# tweetids_219404_359708_2020-09-27T23 39 06
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:50 2022 , we spent  0.39  s for the last processing task.
# tweetids_219404_359708_2020-09-27T23 47 42
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:50 2022 , we spent  0.19  s for the last processing task.
# tweetids_219404_359708_2020-09-27T23 52 18
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:51 2022 , we spent  0.12  s for the last processing task.
# tweetids_219404_359708_2020-09-27T23 55 23
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:51 2022 , we spent  0.29  s for the last processing task.
# tweetids_219404_359708_2020-09-28T00 01 28
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:51 2022 , we spent  0.47  s for the last processing task.
# tweetids_219404_359708_2020-09-28T00 11 48
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:52 2022 , we spent  0.59  s for the last processing task.
# tweetids_219404_359708_2020-09-28T00 23 23
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:52 2022 , we spent  0.5  s for the last processing task.
# tweetids_219404_359708_2020-09-28T00 32 59
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:53 2022 , we spent  0.56  s for the last processing task.
# tweetids_219404_359708_2020-09-28T01 41 19
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:53 2022 , we spent  0.5  s for the last processing task.
# tweetids_219404_359708_2020-09-28T01 51 55
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:54 2022 , we spent  0.21  s for the last processing task.
# tweetids_219404_359708_2020-09-28T01 57 00
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:54 2022 , we spent  0.12  s for the last processing task.
# tweetids_219404_359708_2020-09-28T02 00 56
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:54 2022 , we spent  0.29  s for the last processing task.
# tweetids_219404_359708_2020-09-28T02 07 48
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:55 2022 , we spent  0.44  s for the last processing task.
# tweetids_219404_359708_2020-09-28T02 16 24
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:55 2022 , we spent  0.41  s for the last processing task.
# tweetids_219404_359708_2020-09-28T02 24 29
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:55 2022 , we spent  0.38  s for the last processing task.
# tweetids_219404_359708_2020-09-28T02 32 05
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:56 2022 , we spent  0.38  s for the last processing task.
# tweetids_219404_359708_2020-09-28T02 39 40
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:56 2022 , we spent  0.34  s for the last processing task.
# tweetids_219404_359708_2020-09-28T02 46 46
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:56 2022 , we spent  0.17  s for the last processing task.
# tweetids_219404_359708_2020-09-28T02 50 52
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:56 2022 , we spent  0.13  s for the last processing task.
# tweetids_219404_359708_2020-09-28T02 53 57
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:57 2022 , we spent  0.36  s for the last processing task.
# tweetids_219404_359708_2020-09-28T03 01 02
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:57 2022 , we spent  0.65  s for the last processing task.
# tweetids_219404_359708_2020-09-28T03 12 38
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:58 2022 , we spent  0.75  s for the last processing task.
# tweetids_219404_359708_2020-09-28T03 28 59
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:49:59 2022 , we spent  0.75  s for the last processing task.
# tweetids_219404_359708_2020-09-28T03 43 51
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:00 2022 , we spent  0.7  s for the last processing task.
# tweetids_219404_359708_2020-09-28T03 57 27
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:00 2022 , we spent  0.5  s for the last processing task.
# tweetids_219404_359708_2020-09-28T04 07 33
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:00 2022 , we spent  0.22  s for the last processing task.
# tweetids_219404_359708_2020-09-28T04 12 38
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:00 2022 , we spent  0.16  s for the last processing task.
# tweetids_219404_359708_2020-09-28T04 16 13
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:01 2022 , we spent  0.48  s for the last processing task.
# tweetids_219404_359708_2020-09-28T05 23 53
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:02 2022 , we spent  0.8  s for the last processing task.
# tweetids_219404_359708_2020-09-28T05 39 14
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:02 2022 , we spent  0.76  s for the last processing task.
# tweetids_219404_359708_2020-09-28T05 54 19
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:03 2022 , we spent  0.73  s for the last processing task.
# tweetids_219404_359708_2020-09-28T06 07 55
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:04 2022 , we spent  0.67  s for the last processing task.
# tweetids_219404_359708_2020-09-28T06 20 32
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:04 2022 , we spent  0.53  s for the last processing task.
# tweetids_219404_359708_2020-09-28T06 30 37
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:05 2022 , we spent  0.25  s for the last processing task.
# tweetids_219404_359708_2020-09-28T06 35 42
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:05 2022 , we spent  0.17  s for the last processing task.
# tweetids_219404_359708_2020-09-28T06 39 47
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:05 2022 , we spent  0.44  s for the last processing task.
# tweetids_219404_359708_2020-09-28T06 49 39
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:06 2022 , we spent  0.74  s for the last processing task.
# tweetids_219404_359708_2020-09-28T07 03 44
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:07 2022 , we spent  0.76  s for the last processing task.
# tweetids_219404_359708_2020-09-28T07 18 20
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:07 2022 , we spent  0.75  s for the last processing task.
# tweetids_219404_359708_2020-09-28T07 32 56
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:08 2022 , we spent  0.77  s for the last processing task.
# tweetids_219404_359708_2020-09-28T07 48 32
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:09 2022 , we spent  0.64  s for the last processing task.
# tweetids_219404_359708_2020-09-28T08 00 38
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:09 2022 , we spent  0.28  s for the last processing task.
# tweetids_219404_359708_2020-09-28T08 06 14
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:09 2022 , we spent  0.19  s for the last processing task.
# tweetids_219404_359708_2020-09-28T08 10 19
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:10 2022 , we spent  0.54  s for the last processing task.
# tweetids_219404_359708_2020-09-28T09 20 18
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:11 2022 , we spent  0.82  s for the last processing task.
# tweetids_219404_359708_2020-09-28T09 38 48
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:12 2022 , we spent  0.84  s for the last processing task.
# tweetids_219404_359708_2020-09-28T09 57 41
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:12 2022 , we spent  0.75  s for the last processing task.
# tweetids_219404_359708_2020-09-28T10 13 11
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:13 2022 , we spent  0.71  s for the last processing task.
# tweetids_219404_359708_2020-09-28T10 27 17
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:14 2022 , we spent  0.65  s for the last processing task.
# tweetids_219404_359708_2020-09-28T10 40 37
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:14 2022 , we spent  0.3  s for the last processing task.
# tweetids_219404_359708_2020-09-28T10 48 35
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:14 2022 , we spent  0.22  s for the last processing task.
# tweetids_219404_359708_2020-09-28T10 53 40
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:15 2022 , we spent  0.63  s for the last processing task.
# tweetids_219404_359708_2020-09-28T11 06 15
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:16 2022 , we spent  1.2  s for the last processing task.
# tweetids_219404_359708_2020-09-28T11 26 21
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:17 2022 , we spent  1.28  s for the last processing task.
# tweetids_219404_359708_2020-09-28T11 46 27
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:18 2022 , we spent  0.95  s for the last processing task.
# tweetids_219404_359708_2020-09-28T12 03 33
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:19 2022 , we spent  0.94  s for the last processing task.
# tweetids_219404_359708_2020-09-28T17 15 01
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:20 2022 , we spent  0.73  s for the last processing task.
# tweetids_219404_359708_2020-09-28T18 00 45
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:20 2022 , we spent  0.37  s for the last processing task.
# tweetids_219404_359708_2020-09-28T18 07 36
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:21 2022 , we spent  0.26  s for the last processing task.
# tweetids_219404_359708_2020-09-28T18 11 12
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:21 2022 , we spent  0.53  s for the last processing task.
# tweetids_219404_359708_2020-09-28T18 19 47
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:22 2022 , we spent  0.77  s for the last processing task.
# tweetids_219404_359708_2020-09-28T18 32 23
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:23 2022 , we spent  0.65  s for the last processing task.
# tweetids_219404_359708_2020-09-28T18 46 24
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:23 2022 , we spent  0.62  s for the last processing task.
# tweetids_219404_359708_2020-09-28T18 59 00
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:24 2022 , we spent  0.57  s for the last processing task.
# tweetids_219404_359708_2020-09-28T19 10 36
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:24 2022 , we spent  0.46  s for the last processing task.
# tweetids_219404_359708_2020-09-28T19 21 03
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:24 2022 , we spent  0.23  s for the last processing task.
# tweetids_219404_359708_2020-09-28T19 26 08
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:25 2022 , we spent  0.14  s for the last processing task.
# tweetids_219404_359708_2020-09-28T19 29 43
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:25 2022 , we spent  0.35  s for the last processing task.
# tweetids_219404_359708_2020-09-28T19 36 48
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:26 2022 , we spent  0.65  s for the last processing task.
# tweetids_219404_359708_2020-09-28T19 50 39
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:26 2022 , we spent  0.75  s for the last processing task.
# tweetids_219404_359708_2020-09-28T20 05 59
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:27 2022 , we spent  0.78  s for the last processing task.
# tweetids_219404_359708_2020-09-28T20 19 05
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:28 2022 , we spent  0.77  s for the last processing task.
# tweetids_219404_359708_2020-09-28T20 30 11
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:29 2022 , we spent  0.66  s for the last processing task.
# tweetids_219404_359708_2020-09-28T20 38 47
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:29 2022 , we spent  0.23  s for the last processing task.
# tweetids_219404_359708_2020-09-28T20 43 52
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:29 2022 , we spent  0.16  s for the last processing task.
# tweetids_219404_359708_2020-09-28T20 47 57
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:29 2022 , we spent  0.44  s for the last processing task.
# tweetids_219404_359708_2020-09-28T20 58 52
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:30 2022 , we spent  0.68  s for the last processing task.
# tweetids_219404_359708_2020-09-28T21 12 27
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:31 2022 , we spent  0.71  s for the last processing task.
# tweetids_219404_359708_2020-09-28T21 26 03
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:31 2022 , we spent  0.77  s for the last processing task.
# tweetids_219404_359708_2020-09-28T21 40 09
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:32 2022 , we spent  0.77  s for the last processing task.
# tweetids_219404_359708_2020-09-28T21 55 15
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:33 2022 , we spent  0.55  s for the last processing task.
# tweetids_219404_359708_2020-09-28T22 06 20
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:33 2022 , we spent  0.26  s for the last processing task.
# tweetids_219404_359708_2020-09-28T22 11 56
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:33 2022 , we spent  0.19  s for the last processing task.
# tweetids_219404_359708_2020-09-28T22 16 01
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:34 2022 , we spent  0.49  s for the last processing task.
# tweetids_219404_359708_2020-09-28T22 26 27
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:35 2022 , we spent  0.76  s for the last processing task.
# tweetids_219404_359708_2020-09-28T22 41 32
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:35 2022 , we spent  0.79  s for the last processing task.
# tweetids_219404_359708_2020-09-28T22 57 39
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:36 2022 , we spent  0.73  s for the last processing task.
# tweetids_219404_359708_2020-09-28T23 11 45
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:37 2022 , we spent  0.67  s for the last processing task.
# tweetids_219404_359708_2020-09-28T23 24 21
# Length is consitent:  True
# No Error occurs:  True
# Now is  Sun Apr  3 21:50:37 2022 , we spent  0.53  s for the last processing task.
